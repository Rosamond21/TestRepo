# %% [markdown]
# # Test

# %% [markdown]
# 1. Test I
# 2. Test II
# 3. Test III

# %% [markdown]
# |TESTING|
# |-------|
# |1. Test I|
# |2. Test II|
# |3. Test III|

# %%
(3*4)+5
# Out:
# 17

# %%
turn 200 minutes into hours
# Out:
#   Cell In[9], line 1
#     turn 200 minutes into hours
#          ^
# SyntaxError: invalid syntax

# %%
#convert 200 minutes into hours

# %%
200/60
# Out:
# 3.3333333333333335

# %%
200minutes/60
# Out:
#   Cell In[13], line 1
#     200minutes/60
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **Objectives**
# - Python
# - R
# - SQL
# - Scala
# - Java
